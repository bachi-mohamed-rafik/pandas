# %% [markdown]
# <a href="https://colab.research.google.com/github/bachi-mohamed-rafik/pandas/blob/main/Visualization_tips.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Visualization tips

# %%
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url = 'https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/07_Visualization/Tips/tips.csv'
tips = pd.read_csv(url)
print(tips)


print(tips.columns)

tips=tips.loc[:, ~tips.columns.str.contains('^Unnamed')]
print(tips)


print(tips.columns)
# Out:
#      Unnamed: 0  total_bill   tip     sex smoker   day    time  size
# 0             0       16.99  1.01  Female     No   Sun  Dinner     2
# 1             1       10.34  1.66    Male     No   Sun  Dinner     3
# 2             2       21.01  3.50    Male     No   Sun  Dinner     3
# 3             3       23.68  3.31    Male     No   Sun  Dinner     2
# 4             4       24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...         ...   ...     ...    ...   ...     ...   ...
# 239         239       29.03  5.92    Male     No   Sat  Dinner     3
# 240         240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241         241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242         242       17.82  1.75    Male     No   Sat  Dinner     2
# 243         243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 8 columns]
# Index(['Unnamed: 0', 'total_bill', 'tip', 'sex', 'smoker', 'day', 'time',
#        'size'],
#       dtype='object')
# ...

# %%
# Plot the total_bill column histogram
print("Plot the total_bill column histogram:")

ax = tips.plot.scatter(x='tip',
                      y='total_bill')

ax.plot(kind='bar')
plt.xlabel('tip')
plt.ylabel('total_bill')
plt.title(' the total_bill column histogram')
plt.show()
# Out:
# Plot the total_bill column histogram:

# %%
# Create a scatter plot presenting the relationship between total_bill and tip
print("Create a scatter plot presenting the relationship between total_bill and tip:")

ax1 = tips.plot.scatter(x='total_bill',
                      y='tip',
                     )

ax1.plot(kind='bar')
plt.xlabel('total_bill')
plt.ylabel('tip')
plt.title('scatter plot presenting the relationship between total_bill and tip')
plt.show()
# Out:
# Create a scatter plot presenting the relationship between total_bill and tip:

# %%
# Create one image with the relationship of total_bill, tip and size.
print("Create one image with the relationship of total_bill, tip and size:")
print(sns.pairplot(tips))
# Out:
# Create one image with the relationship of total_bill, tip and size:
# ...

# %%
# Present the relationship between days and total_bill value
print("Present the relationship between days and total_bill value:")

sns.stripplot(x = "day", y = "total_bill", data = tips, jitter = True)
# Out:
# Present the relationship between days and total_bill value:

# %%
# Create a scatter plot with the day as the y-axis and tip as the x-axis, differ the dots by sex
print("Create a scatter plot with the day as the y-axis and tip as the x-axis, differ the dots by sex:")

sns.stripplot(x = "tip", y = "day", hue = "sex", data = tips, jitter = True)
# Out:
# Create a scatter plot with the day as the y-axis and tip as the x-axis, differ the dots by sex:

# %%
# Create a box plot presenting the total_bill per day differetiation the time (Dinner or Lunch)
print("Create a box plot presenting the total_bill per day differetiation the time (Dinner or Lunch):")

tips.plot.box(grid='True')
# Out:
# Create a box plot presenting the total_bill per day differetiation the time (Dinner or Lunch):
